# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.inspection import DecisionBoundaryDisplay
import pandas as pd

# %%
df = pd.read_csv('data/knn_4_dataset.csv')  # Load the dataset
df.head(5)
# Out:
#    feature_1  feature_2  y
# 0  -9.297689   6.473679  3
# 1  -9.698741   6.938967  3
# 2  -1.686653   7.793442  0
# 3  -7.097308  -5.781333  2
# 4 -10.876452   6.315437  3

# %%
X = df[['feature_1', 'feature_2']].values
y = df['y'].values

# %%
# Instantiate and train K-NN classifier
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X,y)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
# Display the decision boundary and scatter the training points, similar to the lesson
plt.figure(figsize=(8,6))
DecisionBoundaryDisplay.from_estimator(
    knn,
    X,
    response_method='predict',
    alpha=0.3,
    xlabel='Feature 1',
    ylabel='Feature 2',
)
plt.scatter(X[:,0], X[:,1], c=y)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('K-NN Decision Boundary')
plt.show()
