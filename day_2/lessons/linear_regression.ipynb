# %%
# Import necessary libraries
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read synthetic data from CSV file, get X and y
data = pd.read_csv('data/regression_data.csv')
x=data[['x']].to_numpy()
y=data['y'].to_numpy()

# %%
X.shape, y.shape # Check the shapes of X and y, notice that the shape of X is (# of data points, # of features) and the shape of y is (# of data points,)

# %%
# Plot the data
plt.figure(figsize=(5.5))
plt.scatter(X, y, color='blue', label='Data points')
plt.xlable('x')
plt.ylabel('y')
plt.title('Synthetic Data')
plt.legend()
plt.show()

# %%
# Create and train the linear regression model, get the estimated parameters

# %%
# generate predictions

# plot data and fitted line

# %%
# Calculate and print the R-squared value
