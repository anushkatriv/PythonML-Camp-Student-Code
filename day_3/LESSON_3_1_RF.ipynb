# %%
# import necessary libraries
import pandas as pd

# %%
# Load artificial dataset
df = pd.read_csv("data/noisy_random_forest_data.csv")
X = df.iloc[:,0:19]
y = df.iloc[:,20]

df.head()
# Out:
#          x1        x2        x3        x4        x5         x6        x7  \
# 0 -0.682978 -3.041389  0.764031  2.253549  1.215168  -5.599880  2.636479
# 1 -3.362943 -0.092730  0.353924  1.062386  0.370173  -8.168574  1.683731
# 2 -4.733632 -0.557812 -1.184263  0.511358 -0.174942  -5.198912  2.249468
# 3 -2.016468 -1.412197  2.142229  0.097927  0.163680   7.761110 -1.804952
# 4  9.192749  4.224388  0.058684  0.453873  0.227844 -10.854606 -1.954233
#
#          x8        x9       x10  ...       x12       x13       x14       x15  \
# 0  1.358783  0.188386 -1.902607  ... -2.944158  0.503966 -1.438655 -5.467180
# 1  2.742118 -3.737784 -4.000227  ... -0.432925  1.836486  1.073371 -1.255741
# 2  4.898656 -2.985691 -0.213765  ... -0.228213 -0.015742 -0.554086  0.548549
# 3 -0.048102  2.130375  2.080620  ... -2.201108  1.420715  1.019506  0.821615
# 4  3.513025  3.206850 -2.615778  ...  1.185079 -3.920354 -1.009823 -1.645861
#
#         x16       x17       x18       x19       x20  label
# 0 -1.294597  0.915047 -3.344394 -5.083016 -5.409001      0
# 1  0.857872 -1.723997  2.647762 -3.610289 -2.284913      0
# 2  0.076345 -0.145500  4.350806 -2.054308  0.530234      0
# 3  2.327118  0.267749  1.755186  6.198166  4.549046      1
# 4 -0.148868 -0.374367 -3.149086 -5.508283 -2.194265      0
#
# [5 rows x 21 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %%
# train Decision Tree Classifier
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(min_samples_leaf=4, min_samples_split=25)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(min_samples_leaf=4, min_samples_split=25)

# %%
# Evaluate performance of model using test data
y_pred = model.predict(X_test)
y_pred_train = model.predict(X_train)

# %%
# import necessary libraries and print confusion matrix
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
print(confusion_matrix(y_test, y_pred))
# Out:
# [[854 166]
#  [140 840]]

# %%
# print classification report for evaluation metrics
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85      1020
#            1       0.83      0.86      0.85       980
#
#     accuracy                           0.85      2000
#    macro avg       0.85      0.85      0.85      2000
# weighted avg       0.85      0.85      0.85      2000

# %%
# print accuracy score for evaluation
print(accuracy_score(y_test, y_pred))
print(accuracy_score(y_train, y_pred_train))
# Out:
# 0.847
# 0.9185
